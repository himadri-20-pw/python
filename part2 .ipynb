# %% [markdown]
# # Statistics Part 2

# %% [markdown]
# ### Q1) What is hypothesis testing in statistics?

# %% [markdown]
# #### ANS- In statistics,Hypothesis testing is a claim or statement or an assumption about a population parameter that can be tested using statistical methods.A hypothesis is an educated guess about something in the world around you. It should be testable, either by experiment or observation.
#
# #### For example, if we say that “Dhoni is the best Indian Captain ever.” We are making this assumption based on the average wins and losses the team had under his captaincy.  We can test this statement based on all the match data.

# %% [markdown]
# ### Q2) What is the null hypothesis, and how does it differ from the alternative hypothesis?

# %% [markdown]
# #### ANS- The null hypothesis is the hypothesis to be tested for possible rejection under the assumption that it is true. In simple words it  is initial or default assumption. The concept of the null is similar to innocent until proven guilty We assume innocence until we have enough evidence to prove that a suspect is guilty.H0 denotes it.Example-person is not gulity.
# #### The null hypothesis (H0) states that there is no significant relationship or difference between variables, while the alternative hypothesis (H1 or Ha) proposes that there is a relationship or difference. Null hypothesis represents the status quo or a baseline assumption to test against where as alternative hypothesis what you want to prove or support with evidence.

# %% [markdown]
# ### Q3) What is the significance level in hypothesis testing, and why is it important?

# %% [markdown]
# #### ANS- In hypothesis testing, the significance level, denoted by α (alpha), is the probability of rejecting the null hypothesis when it is actually true.It's a predetermined threshold used to determine if the evidence against the null hypothesis is strong enough to be considered statistically significant.Hypothesis testing is important as :-
# #### Controls Error Rate:
# The significance level sets a boundary for how much risk you're willing to take in wrongly rejecting the null hypothesis. Lower α = more cautious testing.
# #### Determines the Critical Value:
# It helps define the critical region: the set of values for which the null hypothesis is rejected.For example, in a z-test, α determines the z-score threshold (e.g., ±1.96 for α = 0.05 in a two-tailed test).
# #### Affects Statistical Power:
# There’s a trade-off: lowering α reduces Type I error but increases the risk of a Type II error (failing to reject a false null hypothesis).
# #### Used in p-value Comparison:
# A result is considered statistically significant if the p-value < α.This helps you decide whether your test results provide enough evidence to reject the null hypothesis.

# %% [markdown]
# ### Q4) What does a P-value represent in hypothesis testing?

# %% [markdown]
# #### The P-value is the probability value,calculatednfrom a statistical test.P-value in hypothesis testing is used to decide whether to reject a null hypothesis or not.

# %% [markdown]
# ### Q5) How do you interpret the P-value in hypothesis testing?

# %% [markdown]
# #### ANS- In hypothesis testing, the p-value represents the probability of obtaining a result as extreme as, or more extreme than, the one observed in a sample, assuming the null hypothesis is true.It is also called the probability of observing the data (or more extreme data) if the null hypothesis were true. Essentially, it quantifies the strength of evidence against the null hypothesis.

# %% [markdown]
# ### Q6) What are Type 1 and Type 2 errors in hypothesis testing?

# %% [markdown]
# #### ANS- Type 1 error:- It is the rejection of the null hypothesis when it is actually True.
# Example:- an innocent person is convicted.
# #### Type 2 error:- It is the failure to reject the null hypothesis that is actually false.
# Example:- A gulity person may not be convicted.

# %% [markdown]
# ### Q7) What is the difference between a one-tailed and a two-tailed test in hypothesis testing?

# %% [markdown]
# #### ANS- If the alternate hypothesis gives the alternate in both directions (less than and greater than) of the value of the parameter specified in the null hypothesis, it is called a two-tailed test.Suppose the alternate hypothesis gives the alternate in only one direction (either less than or greater than) of the value of the parameter specified in the null hypothesis. In that case, it is called the One-tailed test.

# %% [markdown]
# ### Q8) What is the Z-test, and when is it used in hypothesis testing?

# %% [markdown]
# #### ANS- Z-test is a statistical hypothesis test used to determine if there's a significant difference between a sample mean and a population mean, or between the means of two populations, when the population standard deviation is known and the sample size is large (n > 30). It relies on the normal distribution to approximate the distribution of the test statistic. Z-tests are generally used when the sample size is 30 or more (n ≥ 30), the sample mean can be reasonably approximated by a normal distribution, making the Z-test suitable.Z-tests can be used to compare a sample mean to a hypothesized population mean or to compare the means of two independent populations.

# %% [markdown]
# ### Q9) How do you calculate the Z-score, and what does it represent in hypothesis testing?

# %% [markdown]
# #### ANS- To calculate the Z-score:-
# #### 1. Identify the population mean (μ) and standard deviation (σ).
# #### 2. Find the difference between the data point (x) and the population mean (μ).
# #### 3. Divide the difference by the population standard deviation (σ).
# #### formula:- z = (x - μ) / σ
# #### In hypothesis testing, it represents how many standard deviations a sample statistic (like a sample mean) is away from the hypothesized population mean. This allows you to determine if the observed sample is likely to have come from the population with the hypothesized mean. If the Large Z-score , it indicates the sample statistic is far from the hypothesized population mean, suggesting a strong difference between the sample and population.If the Small Z-score, it indicates the sample statistic is close to the hypothesized population mean, suggesting little difference between the sample and population. If the Critical Values, Z-scores are compared to critical values (determined by the chosen significance level) to decide whether to reject or fail to reject the null hypothesis.

# %% [markdown]
# ### Q10) What is the T-distribution, and when should it be used instead of the normal distribution?

# %% [markdown]
# #### ANS- The t-distribution is a probability distribution used in statistics, particularly when dealing with small sample sizes or when the population standard deviation is unknown. It's similar to the normal distribution (z-distribution) in shape but has heavier tails, meaning there's a greater probability of extreme values.
# #### we use t-distribution instead of normal distribution-
# ##### When you have a small sample (typically n < 30), and the population standard deviation (σ) is unknown, the t-distribution is preferred for constructing confidence intervals or performing hypothesis tests.
# ##### The t-distribution is used to find critical values for a confidence interval when the data is approximately normally distributed and the population standard deviation is unknown.
# ##### T-tests, used for comparing sample means, rely on the t-distribution to determine the statistical significance of the difference between the means.

# %% [markdown]
# ### Q11) What is the difference between a Z-test and a T-test?

# %% [markdown]
# #### ANS- The difference between a Z-test and a T-test?
#
# #### Population Standard Deviation (σ):-
# Z-test: σ is known.
# T-test: σ is unknown.
#
# #### Sample Size:-
# Z-test: Typically used when n ≥ 30 (large sample).
# T-test: Used when n < 30 (small sample), but also valid for large n.
#
# #### Distribution Used:-
# Z-test: Uses the standard normal (Z) distribution.
# T-test: Uses the Student’s t-distribution.
# #### Shape of Distribution:-
# Z-distribution: Fixed, symmetric.
# T-distribution: Symmetric but with heavier tails, especially with smaller sample sizes.
#
# #### Degrees of Freedom (df):-
# Z-test: Not applicable.
# T-test: Depends on sample size (usually df = n − 1).
#
# #### Applications:-
# Z-test:
# Test for population mean (with known σ)
# Proportion test (large samples)
# T-test:
# One-sample t-test
# Two-sample t-test
# Paired t-test
#
# #### Formula:-
# Z = (x̄ - μ) / (σ/νη)
# t=  (x̄ - μ ) / (s/νη)

# %% [markdown]
# ### Q12) What is the T-test, and how is it used in hypothesis testing?

# %% [markdown]
# #### ANS- A t-test is used when the population standard deviation is unknown, especially with smaller samples (less than 30).It is mainly used in the Student's t-distribution.It requires calculation of degrees of freedom.It's use cases Comparing means between two groups, especially when the population standard deviation is unknown.

# %% [markdown]
# ### Q13) What is the relationship between Z-test and T-test in hypothesis testing?

# %% [markdown]
# #### ANS- In hypothesis testing, z-tests and t-tests are both used to compare means, but they differ in their assumptions and applications. Z-tests are typically used for large samples (n > 30) when the population standard deviation is known, or for large samples when the sample standard deviation can be used as an estimate. T-tests are used for small samples (n < 30) or when the population standard deviation is unknown,is mainly used in the Student's t-distribution.

# %% [markdown]
# ### Q14) What is a confidence interval, and how is it used to interpret statistical results?

# %% [markdown]
# #### ANS- A confidence interval is a range of values used to estimate an unknown population parameter based on sample data, along with a level of confidence in that estimate.It is used to interpret statistical results in following ways:-
# #### These percentage (e.g., 95%, 90%) represents the probability that the true population parameter would fall within the calculated interval if the sampling procedure were repeated many times.The interval provides a range of plausible values for the population parameter.It gives a measure of the precision of the estimate: a narrower interval indicates a more precise estimate, while a wider interval suggests greater uncertainty.
# #### Example:If a 95% confidence interval for the average height of all 16-year-olds is 5'4" to 5'8", it means that you are 95% confident that the true average height of all 16-year-olds falls within that range.

# %% [markdown]
# ### Q15) What is the margin of error, and how does it affect the confidence interval?

# %% [markdown]
# #### ANS- The margin of error is a measure of sampling error. It indicates how much the sample result might deviate from the true population value. The MOE directly affects the width of a confidence interval, which is a range of values within which we are confident the true population value lies. The MOE is half the width of the confidence interval. A larger MOE means the interval is wider, encompassing a broader range of potential values, while a smaller MOE makes the interval narrower, suggesting a more precise estimate.

# %% [markdown]
# ### Q16) How is Bayes' Theorem used in statistics, and what is its significance?

# %% [markdown]
# #### ANS- Bayes' Theorem is the core of calculating conditional probabilities, which are probabilities of an event occurring given that another event has already occurred.It allows for the updating of prior probabilities (beliefs) with new evidence, resulting in posterior probabilities (revised beliefs). It's significance are:-
# #### Statistical Inference:
# Bayes' Theorem allows us to make inferences about unknown parameters or hypotheses by incorporating prior information and new data.
# #### Informed Decision-Making:
# It enables us to make better decisions by updating our beliefs as new evidence emerges, leading to more accurate predictions and conclusions.
# #### Handling Uncertainty:
# Bayes' Theorem provides a framework for dealing with uncertainty by quantifying our knowledge and incorporating it into our analysis.

# %% [markdown]
# ### Q17) What is the Chi-square distribution, and when is it used?

# %% [markdown]
# #### ANS- The chi-square distribution is a continuous probability distribution that is often used in hypothesis testing, specifically for categorical data. It's used to determine the significance of differences between observed and expected frequencies or to assess independence between two categorical variables.

# %% [markdown]
# ### Q18) What is the Chi-square goodness of fit test, and how is it applied?

# %% [markdown]
# #### ANS- The chi-square goodness-of-fit test is a statistical method used to determine if the observed distribution of a categorical variable matches a hypothesized distribution. It assesses how well a theoretical distribution fits an observed sample distribution by comparing observed frequencies to expected frequencies. It's applied as:-
# #### 1. Hypothesis:
# Formulate a hypothesis about the distribution of the population (e.g., a uniform distribution, a normal distribution, etc.).
# #### 2. Data Collection:
# Collect sample data and organize it into categories or intervals.
# #### 3. Expected Frequencies:
# Calculate the expected frequencies for each category based on the hypothesized distribution.
# #### 4. Chi-Square Statistic:
# Calculate the chi-square statistic, which measures the difference between observed and expected frequencies.
# #### 5. P-value:
# Determine the p-value associated with the chi-square statistic using a chi-square distribution table or statistical software.

# %% [markdown]
# ### Q19) What is the F-distribution, and when is it used in hypothesis testing?

# %% [markdown]
# #### ANS- The F-distribution is a probability distribution that is useful in the context of complaring variances of two or more sample.It is right skewed and takes only non negative values.It is used in hypothesis testing as:-
# #### Comparing Variances:
# The F-distribution is used when you want to determine if the variances of two or more populations are equal. This is often done in ANOVA to compare the means of multiple groups.
# #### Model Fit:
# In regression analysis, the F-distribution helps assess whether including additional predictors or a different model significantly improves the fit compared to a simpler model.
# #### Assessing Goodness of Fit:
# The F-distribution can also be used to evaluate the overall fit of a statistical model to the data, ensuring it adequately captures the relationships and variances.

# %% [markdown]
# ### Q20) What is an ANOVA test, and what are its assumptions?

# %% [markdown]
# #### ANS- ANOVA is a statistical method used to compare the means of 2 or more groups.It is generally ANOVA is used for more than 2 groups.
# #### Assumptions of ANOVA
# ##### The population from which samples are drawn should be normally distributed.
# ##### The sample should be independent of each other/random.
# ##### Absence of outliers.
# ##### Homogenerity of varience:- Homogenerity means that the varience among the groups should be approximately equal.

# %% [markdown]
# ### Q21) What are the different types of ANOVA tests?

# %% [markdown]
# #### ANS- The different types of ANOVA tests are:-
# #### one way ANOVA:- one factor with atleast two levels,and levels are independent.
# #### Repeated measures ANOVA:- one factor with atleast two levels but level are dependent.
# #### Factorial ANOVA:- Two or more factors each of which atleast two levels. Levels can be either dependent,independent,or both.It is also called as two way ANOVA ,which deals with only two factors.

# %% [markdown]
# ### Q22) What is the F-test, and how does it relate to hypothesis testing?

# %% [markdown]
# #### ANS- An F-test is a statistical test that compares the variances of two or more populations to determine if there is a significant difference between their means. It's a core component of hypothesis testing, specifically within the context of the analysis of variance (ANOVA).F-tests are used in hypothesis testing to determine if there is a significant difference between the means of two or more groups. They achieve this by comparing the variance between the groups to the variance within each group and utilizing the F-distribution to make a decision about the null hypothesis.

# %% [markdown]
# # Practical Part - 1

# %% [markdown]
# ### Q1) Write a Python program to generate a random variable and display its value.

# %% [markdown]
# #### ANS-

# %%
import random
random_var= random.random()
print("The generated random variable is:", random_var)
# Out:
# The generated random variable is: 0.4980020906714384

# %% [markdown]
# ### Q2) Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
low = 1
high = 7
x = np.arange(low, high)
n = high - low
pmf = np.ones(n) / n  # Each value gets probability 1/n

plt.bar(x, pmf, width=0.6, color='skyblue', edgecolor='black')
plt.title('Discrete Uniform Distribution PMF')
plt.xlabel('x')
plt.ylabel('P(X = x)')
plt.xticks(x)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Q3) Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %% [markdown]
# #### ANS-

# %%
def bernoulli_pdf(x, p):

    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        return 0.0  # Any other value has probability 0 in a Bernoulli distribution

# %%
print(bernoulli_pdf(1, 0.6))  
print(bernoulli_pdf(0, 0.6))  
print(bernoulli_pdf(2, 0.6))
# Out:
# 0.6
# 0.4
# 0.0

# %% [markdown]
# ### Q4) Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt

b = np.random.binomial(n=10, p = 0.5, size= 1000)
plt.hist(b)
plt.show()

# %% [markdown]
# ### Q5) Create a Poisson distribution and visualize it using Python.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

p = np.random.poisson(lam = 5, size = 1000)
plt.hist(p, bins=20)
plt.show()

# %% [markdown]
# ### Q6) Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
a = 1  
b = 10 
x = np.arange(a, b + 1)
n = len(x)
prob = 1 / n

cdf = np.cumsum([prob] * n)

plt.step(x, cdf, where='post', label='CDF', color='blue')
plt.title(f'Discrete Uniform Distribution CDF (a={a}, b={b})')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.ylim(0, 1.05)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Q7) Generate a continuous uniform distribution using NumPy and visualize it.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
u = np.random.uniform(0, 10, 10000)
plt.hist(u, 30)
plt.title('Continuous Uniform Distribution')
plt.show()

# %% [markdown]
# ### Q8) Simulate data from a normal distribution and plot its histogram.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
mean = 0      
std_dev = 1    #(σ)
size = 10000  
samples = np.random.normal(mean, std_dev, size)

plt.hist(samples,30)
plt.title(f'Histogram of Normal Distribution')
plt.show()

# %% [markdown]
# ### Q9) Write a Python function to calculate Z-scores from a dataset and plot them.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    if std == 0:
        raise ValueError("Standard deviation is zero. Z-scores are undefined.")
    z_scores = (data - mean) / std
    plt.hist(z_scores, bins=50, density=True, alpha=0.7, color='green', edgecolor='black')
    plt.title('Histogram of Z-scores')
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.grid(True)
    plt.show()
    return z_scores

# %%
calculate_and_plot_z_scores([20,40,50,65,86,24,90])
# Out:
# array([-1.29453499, -0.52332266, -0.13771649,  0.44069276,  1.25046571,
#        -1.14029252,  1.40470818])

# %% [markdown]
# ### Q10) Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
population_mean = 5
population = np.random.exponential(population_mean, 10000)

sample_size = 30
num_samples = 1000

sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, sample_size, replace=False) # Sample without replacement
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

plt.figure(figsize=(10, 6))
sns.histplot(sample_means, kde=True, color='skyblue')
plt.title('Distribution of Sample Means (CLT)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Q11) Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
mean = 50
std_dev = 10
sample_size = 100
num_samples = 50
data = np.random.normal(mean, std_dev, sample_size * num_samples)
sample_means = []
for i in range(num_samples):
    sample = data[i*sample_size:(i+1)*sample_size]
    sample_means.append(np.mean(sample))
    
plt.hist(sample_means, bins=20, density=True, alpha=0.7, label="Sample Means Distribution")

x = np.linspace(mean - 3 * (std_dev / np.sqrt(sample_size)), mean + 3 * (std_dev / np.sqrt(sample_size)), 100)
plt.plot(x, 1/(std_dev / np.sqrt(sample_size) * np.sqrt(2 * np.pi)) * np.exp(-(x - mean)*2 / (2 * (std_dev / np.sqrt(sample_size))*2)),
         label="Normal Distribution (CLT)", color="red", linewidth=2)

plt.title("Sampling Distribution of Means (CLT)")
plt.xlabel("Sample Mean")
plt.ylabel("Probability Density")
plt.legend()
plt.show()

# %% [markdown]
# ### Q12) Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():

    x = np.linspace(-4, 4, 200)

    y = norm.pdf(x, 0, 1)
    
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, color='blue')
    plt.title('Standard Normal Distribution (Mean=0, Std=1)')
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.show()

# %%
plot_standard_normal_distribution()

# %% [markdown]
# ### Q13) Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy.stats import binom

n = 10       
p = 0.5
size = 5

random_vars = np.random.binomial(n, p, size)
print("Random variables (number of successes):", random_vars)

probabilities = binom.pmf(random_vars, n, p)
print("Corresponding probabilities:", probabilities)
# Out:
# Random variables (number of successes): [5 8 5 8 3]
# Corresponding probabilities: [0.24609375 0.04394531 0.24609375 0.04394531 0.1171875 ]

# %% [markdown]
# ### Q14) Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
    z_score = (data_point - mean) / std_dev
    return z_score

def compare_to_standard_normal(z_score):
   
    probability = norm.cdf(z_score)
    if z_score > 0:
        description = f"The data point is {z_score:.2f} standard deviations above the mean. The probability of a value less than this is {probability:.4f}."
    elif z_score < 0:
        description = f"The data point is {abs(z_score):.2f} standard deviations below the mean. The probability of a value less than this is {probability:.4f}."
    else:
        description = "The data point is equal to the mean. The probability of a value less than this is 0.5."
    return probability, description

# %%
data_point = 10
mean = 5
std_dev = 2

z_score = calculate_z_score(data_point, mean, std_dev)
probability, description = compare_to_standard_normal(z_score)

print(f"Z-score: {z_score:.2f}")
print(description)
# Out:
# Z-score: 2.50
# The data point is 2.50 standard deviations above the mean. The probability of a value less than this is 0.9938.

# %% [markdown]
# ### Q15) Implement hypothesis testing using Z-statistics for a sample dataset.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy.stats import norm

sample_data = [105, 110, 98, 100, 102, 97, 103, 108, 99, 101]

mu_0 = 100            
sigma = 5
alpha = 0.05      
n = len(sample_data)
sample_mean = np.mean(sample_data)

z = (sample_mean - mu_0) / (sigma / np.sqrt(n))

z_critical = norm.ppf(1 - alpha / 2)

p_value = 2 * (1 - norm.cdf(abs(z)))

print("Sample Mean:", sample_mean)
print("Z-statistic:", z)
print("Z-critical value (±):", z_critical)
print("P-value:", p_value)

if abs(z) > z_critical:
    print("Reject the null hypothesis (H₀).")
else:
    print("Fail to reject the null hypothesis (H₀).")
# Out:
# Sample Mean: 102.3
# Z-statistic: 1.4546477236774529
# Z-critical value (±): 1.959963984540054
# P-value: 0.1457668118131128
# Fail to reject the null hypothesis (H₀).

# %% [markdown]
# ### Q16) Create a confidence interval for a dataset using Python and interpret the result.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import scipy.stats as stats

data = [85, 87, 90, 88, 86, 91, 89, 84, 90, 92]

mean = np.mean(data)
sem = stats.sem(data)  
confidence = 0.95
h = sem * stats.t.ppf((1 + confidence) / 2.0, len(data) - 1)
lower_bound = mean - h
upper_bound = mean + h

print(f"Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Mean: 88.20
# 95% Confidence Interval: (86.30, 90.10)

# %% [markdown]
# ### Q17) Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy import stats

np.random.seed(42)

data = np.random.normal(loc=50, scale=10, size=100)

mean = np.mean(data)
sem = stats.sem(data)

confidence = 0.95
ci = stats.t.interval(confidence, df=len(data)-1, loc=mean, scale=sem)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({ci[0]:.2f}, {ci[1]:.2f})")
# Out:
# Sample Mean: 48.96
# 95% Confidence Interval: (47.16, 50.76)

# %% [markdown]
# ### Q18) Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_normal_pdf(mean, std_dev, x_range=(-5, 5), num_points=1000):
    x = np.linspace(x_range[0], x_range[1], num_points)

    pdf = stats.norm.pdf(x, mean, std_dev)

    plt.figure(figsize=(8, 6))
    plt.plot(x, pdf, label=f'μ={mean}, σ={std_dev}')
    plt.title('Normal Distribution PDF')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
mean = 0 
std_dev = 1
plot_normal_pdf(mean, std_dev)

# %% [markdown]
# ### Q19) Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %% [markdown]
# #### ANS-

# %%
import scipy.stats
from scipy.stats import poisson
lambda_value = 5
k_value = 3
cdf_value = poisson.cdf(k_value, lambda_value)
print("The CDF for k =", k_value, "is:", cdf_value)
# Out:
# The CDF for k = 3 is: 0.2650259152973615

# %% [markdown]
# ### Q20) Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %% [markdown]
# #### ANS-

# %%
import random
a, b = 2, 10
simulated_value = random.uniform(a, b)
expected_value = (a + b) / 2

print("Simulated value:", simulated_value)
print("Expected value:", expected_value)
# Out:
# Simulated value: 4.3264570628310155
# Expected value: 6.0

# %% [markdown]
# ### Q21) Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset1 = np.random.normal(loc=50, scale=10, size=1000) 
dataset2 = np.random.normal(loc=50, scale=20, size=1000) 

std1 = np.std(dataset1, ddof=1)  
std2 = np.std(dataset2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(dataset1, color='blue', label='Dataset 1', kde=True, stat="density", bins=30)
sns.histplot(dataset2, color='orange', label='Dataset 2', kde=True, stat="density", bins=30)
plt.title('Histogram Comparison')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

plt.subplot(1, 2, 2)
sns.boxplot(data=[dataset1, dataset2], palette=['blue', 'orange'])
plt.xticks([0, 1], ['Dataset 1', 'Dataset 2'])
plt.title('Boxplot Comparison')

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 9.83
# Standard Deviation of Dataset 2: 20.00

# %% [markdown]
# ### Q23) Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
data = np.random.normal(0, 1, 1000)
range_val = np.max(data) - np.min(data)
q75, q25 = np.percentile(data, [75 ,25])
iqr_val = q75 - q25
print("range_val:",range_val)
print("IQR:",iqr_val)
# Out:
# range_val: 5.997813313939739
# IQR: 1.3088054162487002

# %% [markdown]
# ### Q24) Implement Z-score normalization on a dataset and visualize its transformation.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)
mean = np.mean(data)
std = np.std(data)
z_normalized_data = (data - mean) / std

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(data, bins=30, kde=True, color='skyblue')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.legend()
plt.subplot(1, 2, 2)
sns.histplot(z_normalized_data, bins=30, kde=True, color='lightgreen')
plt.title('Z-score Normalized Data Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.axvline(0, color='red', linestyle='--', label='Mean = 0')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q25) Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):

    skew_val = skew(data)
    kurt_val = kurtosis(data)  
    return skew_val, kurt_val

# %%
np.random.seed(42)
data = np.random.normal(loc=0, scale=1, size=1000)

skewness, kurt = calculate_skewness_kurtosis(data)
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis (excess): {kurt:.4f}")
# Out:
# Skewness: 0.1168
# Kurtosis (excess): 0.0662

# %% [markdown]
# # Practical Part - 2

# %% [markdown]
# ### Q1) Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %% [markdown]
# #### ANS-

# %%
import math
from scipy.stats import norm

def z_test(sample_mean, sample_std, sample_size, population_mean, alpha):
   
    z_statistic = (sample_mean - population_mean) / (sample_std / math.sqrt(sample_size))

    if z_statistic > 0:
        p_value = 2 * (1 - norm.cdf(z_statistic))
    else:
        p_value = 2 * norm.cdf(z_statistic)

    reject_null = p_value < alpha


    results_string = f"Z-statistic: {z_statistic:.3f}\nP-value: {p_value:.3f}\n"

    if reject_null:
        results_string += "Reject the null hypothesis. The sample mean is significantly different from the population mean.\n"
    else:
        results_string += "Fail to reject the null hypothesis. There is no significant difference between the sample mean and the population mean.\n"

    return z_statistic, p_value, reject_null, results_string

# %%
sample_mean = 52  
sample_std = 8    
sample_size = 50  
population_mean = 50 
alpha = 0.05

z_stat, p_val, reject, results = z_test(sample_mean, sample_std, sample_size, population_mean, alpha)
print(results)
# Out:
# Z-statistic: 1.768
# P-value: 0.077
# Fail to reject the null hypothesis. There is no significant difference between the sample mean and the population mean.

# %% [markdown]
# ### Q2) Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy import stats

np.random.seed(0)

group1 = np.random.normal(loc=5, scale=2, size=100)
group2 = np.random.normal(loc=6, scale=2, size=100) 

t_statistic, p_value = stats.ttest_ind(group1, group2)

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject the null hypothesis: There is not enough evidence to suggest a significant difference.")

print("P-value:", p_value)
# Out:
# Reject the null hypothesis: There is a significant difference between the means.
# P-value: 0.00040627960203625234

# %% [markdown]
# ### Q3) Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    z = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    p_value = 2 * (1 - norm.cdf(abs(z)))
    
    return z, p_value

sample_data = [105, 110, 102, 98, 100, 104, 107]
pop_mean = 100
pop_std = 10

z_stat, p_val = one_sample_z_test(sample_data, pop_mean, pop_std)

print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_val:.3f}")

if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Z-statistic: 0.983
# P-value: 0.326
# Reject the null hypothesis

# %% [markdown]
# ### Q4) Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 100               
sigma = 15
x_bar = 108
n = 36
alpha = 0.05

z = (x_bar - mu) / (sigma / np.sqrt(n))

z_crit = norm.ppf(1 - alpha/2)

p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-statistic: {z:.3f}")
print(f"Critical Z value: ±{z_crit:.3f}")
print(f"P-value: {p_value:.4f}")

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')

plt.fill_between(x, y, where=(x <= -z_crit) | (x >= z_crit), color='red', alpha=0.3, label='Rejection Region')

plt.axvline(z, color='black', linestyle='--', label=f'Z-statistic = {z:.2f}')
plt.axvline(-z_crit, color='red', linestyle='--', label=f'Critical Values = ±{z_crit:.2f}')
plt.axvline(z_crit, color='red', linestyle='--')

plt.title('Two-Tailed Z Test with Decision Region')
plt.xlabel('Z')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-statistic: 3.200
# Critical Z value: ±1.960
# P-value: 0.0014

# %% [markdown]
# ### Q5) Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def simple_error_plot(mu0=0, mu1=1, sigma=1, alpha=0.05):

    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)

    y0 = norm.pdf(x, mu0, sigma)
    y1 = norm.pdf(x, mu1, sigma)

    z_crit = norm.ppf(1 - alpha)
    crit_value = mu0 + z_crit * sigma
    plt.figure(figsize=(8, 5))
    plt.plot(x, y0, label='H₀: μ = μ₀', color='blue')
    plt.plot(x, y1, label='H₁: μ = μ₁', color='green')

    # Type I Error (α): Reject H₀ when true
    plt.fill_between(x, 0, y0, where=(x > crit_value), color='red', alpha=0.4, label='Type I Error (α)')

    # Type II Error (β): Fail to reject H₀ when H₁ is true
    plt.fill_between(x, 0, y1, where=(x <= crit_value), color='orange', alpha=0.4, label='Type II Error (β)')

    plt.axvline(crit_value, color='black', linestyle='--', label='Critical Value')
    plt.title('Type I and Type II Errors')
    plt.xlabel('Test Statistic')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    beta = norm.cdf(crit_value, mu1, sigma)
    power = 1 - beta
    print(f'Type II Error (β): {beta:.4f}')
    print(f'Test Power: {power:.4f}')

# %%
simple_error_plot(mu0=0, mu1=1, sigma=1, alpha=0.05)
# Out:
# Type II Error (β): 0.7405
# Test Power: 0.2595

# %% [markdown]
# ### Q6) Write a Python program to perform an independent T-test and interpret the results.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy import stats

# Sample data for two independent groups
group1 = [20, 22, 19, 24, 30, 25, 21]
group2 = [28, 27, 30, 35, 40, 33, 29]

# Perform independent T-test
t_stat, p_value = stats.ttest_ind(group1, group2)

# Print test results
print("Independent T-Test Results")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level

print("\nInterpretation:")
if p_value < alpha:
    print(f"Since p-value < {alpha}, we reject the null hypothesis.")
    print("There is a statistically significant difference between the two group means.")
else:
    print(f"Since p-value >= {alpha}, we fail to reject the null hypothesis.")
    print("There is no statistically significant difference between the two group means.")
# Out:
# Independent T-Test Results
# T-statistic: -3.8840
# P-value: 0.0022
#
# Interpretation:
# Since p-value < 0.05, we reject the null hypothesis.
# There is a statistically significant difference between the two group means.

# %% [markdown]
# ### Q7) Perform a paired sample T-test using Python and visualize the comparison results.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Sample data
before = [70, 72, 68, 65, 74]
after = [75, 74, 70, 67, 78]

# Paired t-test
t_stat, p_val = ttest_rel(before, after)
print(f"T-statistic: {t_stat:.2f}, P-value: {p_val:.4f}")

# Simple plot
plt.plot(before, label='Before', marker='o')
plt.plot(after, label='After', marker='o')
plt.title('Before vs After')
plt.xlabel('Subject')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# T-statistic: -4.74, P-value: 0.0090

# %% [markdown]
# ### Q8) Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy import stats

np.random.seed(1)
sample = np.random.normal(loc=100, scale=15, size=30)

pop_mean = 100
pop_std = 15

sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
z_p = 2 * (1 - stats.norm.cdf(abs(z_stat)))

t_stat, t_p = stats.ttest_1samp(sample, pop_mean)

print("Sample Mean:", round(sample_mean, 2))
print("--- Z-Test ---")
print("Z Statistic:", round(z_stat, 3), " P-value:", round(z_p, 4))
print("--- T-Test ---")
print("T Statistic:", round(t_stat, 3), " P-value:", round(t_p, 4))
# Out:
# Sample Mean: 99.1
# --- Z-Test ---
# Z Statistic: -0.328  P-value: 0.7427
# --- T-Test ---
# T Statistic: -0.32  P-value: 0.7514

# %% [markdown]
# ### Q9) Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(data, confidence_level=0.95):
    sample_mean = np.mean(data)
    sample_std_dev = np.std(data, ddof=1) 
    degrees_of_freedom = len(data) - 1
    t_critical = stats.t.ppf(1 - (1 - confidence_level) / 2, degrees_of_freedom)
    margin_of_error = t_critical * (sample_std_dev / np.sqrt(len(data)))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# %%
sample_data = [10, 12, 15, 18, 20, 22, 25, 28]
confidence_level = 0.95
lower_bound, upper_bound = calculate_confidence_interval(sample_data, confidence_level)
print(f"The {confidence_level * 100}% confidence interval for the sample mean is: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# The 95.0% confidence interval for the sample mean is: (13.52, 23.98)

# %% [markdown]
# The significance of a confidence interval lies in its ability to quantify the uncertainty associated with an estimate and provide a range of plausible values for the population mean.

# %% [markdown]
# ### Q10) Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
import scipy.stats as st
import math

def calculate_margin_of_error(data, confidence_level):
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  
    sample_size = len(data)
    
    alpha = 1 - confidence_level
    degrees_of_freedom = sample_size - 1

    critical_value = st.t.ppf(1 - alpha/2, degrees_of_freedom)
    standard_error = sample_std / math.sqrt(sample_size)
    margin_of_error = critical_value * standard_error

    return margin_of_error

# %%
sample_data = [72, 78, 68, 80, 75, 71, 77, 73, 70, 74]
confidence_level = 0.95
margin = calculate_margin_of_error(sample_data, confidence_level)
print(f"Margin of error: {margin:.3f}")
# Out:
# Margin of error: 2.694

# %% [markdown]
# ### Q11) Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %% [markdown]
# #### ANS- Bayesian inference in Python involves using Bayes' theorem to update probabilities based on new evidence. This process starts with a prior probability representing initial belief, a likelihood representing the probability of observing evidence given the hypothesis, and a posterior probability representing the updated belief after considering the evidence.

# %%
hypotheses = {
    'fair': 0.5,
    'biased': 0.9
}
priors = {
    'fair': 0.5,
    'biased': 0.5
}

# Observed data
heads = 9
tails = 1
def likelihood(hypothesis_p, heads, tails):
    return (hypothesis_p * heads) * ((1 - hypothesis_p) * tails)

unnormalized_posteriors = {}
for hypothesis, p in hypotheses.items():
    prior = priors[hypothesis]
    like = likelihood(p, heads, tails)
    unnormalized_posteriors[hypothesis] = prior * like

evidence = sum(unnormalized_posteriors.values())
posteriors = {h: up / evidence for h, up in unnormalized_posteriors.items()}

print("Posterior probabilities:")
for h, p in posteriors.items():
    print(f"{h}: {p:.4f}")
# Out:
# Posterior probabilities:
# fair: 0.7353
# biased: 0.2647

# %% [markdown]
# #### process:-
# ##### Define Hypotheses: We assume two possible truths about the coin.
# ##### Assign Priors: We start with equal belief in both.
# ##### Compute Likelihood: For each hypothesis, calculate the likelihood of observing 9 heads and 1 tail.
# ##### Apply Bayes' Theorem:
# ##### Multiply prior and likelihood to get unnormalized posteriors.
# ##### Normalize these to get actual posterior probabilities.
# ##### Interpret: The result tells you which hypothesis is more likely given the data.

# %% [markdown]
# ### Q12) Perform a Chi-square test for independence between two categorical variables in Python.

# %% [markdown]
# #### ANS-

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
 
data = {'Category1': ['A', 'A', 'B', 'B', 'A', 'B', 'A', 'B'],
           'Category2': ['X', 'Y', 'X', 'Y', 'X', 'X', 'Y', 'Y']}
df = pd.DataFrame(data)

  
contingency_table = pd.crosstab(df['Category1'], df['Category2'])
print("Contingency Table:\n", contingency_table)

chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:\n", expected)

alpha = 0.05
print("P-value:", p)
if p <= alpha:
       print("Reject H0: The variables are dependent.")
else:
       print("Fail to reject H0: The variables are independent.")
# Out:
# Contingency Table:
#  Category2  X  Y
# Category1
# A          2  2
# B          2  2
# Chi-square statistic: 0.0
# P-value: 1.0
# Degrees of freedom: 1
# Expected frequencies:
#  [[2. 2.]
#  [2. 2.]]
# P-value: 1.0
# Fail to reject H0: The variables are independent.

# %% [markdown]
# ### Q13) Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
def calculate_expected_frequencies(observed_data):

    observed_data = np.array(observed_data)
    row_totals = observed_data.sum(axis=1)
    col_totals = observed_data.sum(axis=0)
    total = observed_data.sum()
    expected_frequencies = np.outer(row_totals, col_totals) / total
    return expected_frequencies

# %%
observed_data = [
        [20, 30, 50],
        [10, 40, 20],
        [30, 20, 10]
    ]
expected_frequencies = calculate_expected_frequencies(observed_data)
print("Observed Frequencies:")
print(np.array(observed_data))
print("\nExpected Frequencies:")
print(expected_frequencies)
# Out:
# Observed Frequencies:
# [[20 30 50]
#  [10 40 20]
#  [30 20 10]]
#
# Expected Frequencies:
# [[26.08695652 39.13043478 34.7826087 ]
#  [18.26086957 27.39130435 24.34782609]
#  [15.65217391 23.47826087 20.86956522]]

# %% [markdown]
# ### Q14) Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %% [markdown]
# #### ANS-

# %%
import numpy as np
from scipy import stats

observed_frequencies = np.array([10, 12, 8, 15, 14])

total_count = sum(observed_frequencies)
expected_frequencies = np.array([total_count / len(observed_frequencies)] * len(observed_frequencies))

statistic, p_value = stats.chisquare(observed_frequencies, expected_frequencies)

print("Chi-squared statistic:", statistic)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
  print("Reject the null hypothesis (observed data significantly different from expected)")
else:
  print("Fail to reject the null hypothesis (observed data not significantly different from expected)")
# Out:
# Chi-squared statistic: 2.7796610169491522
# P-value: 0.5953486599179687
# Fail to reject the null hypothesis (observed data not significantly different from expected)
